# %% [markdown]
# # d) Demuestre que el modelo neuronal de McCullogh-Pitts puede ser aproximado por una neurona con función de activación sigmoidea con grandes pesos sinápticos

# %% [markdown]
# ![image.png](data:image/png;base64,...)
